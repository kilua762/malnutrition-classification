# %% [markdown]
# <a href="https://colab.research.google.com/github/kilua762/malnutrition-classification/blob/main/stunting_classification_rev_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ai project cycle**

# %% [markdown]
# dalam pembuatan suatu machine learning ada beberapa tahap
# 1. Problem Scopping yaitu penjelasan mengenai permasalahan yang terkait kemudian bisa diselesaikan dengan machine learning.
# 2. Data Accuisition sumber data yang untuk aplikasi "https://github.com/sstevenadi/StuntingDataAnalysis.git"
#
# 3. Data Exploration tahapan pemrosesan data meliputi:
#           a.statistik
#           b.deskriptif
#           c.visualitatif
# 4. modelling algoritma yang digunakan dalam pengklasifikasian data
# 5. penjabaran hasil yang didapat untuk menguji akurasi data yang akan digunakan.
# 6. deployment pengaplikasian dalam bentuk web menggunakan Flask (framework phython) memudahkan pengguna

# %% [markdown]
# # **Data Exploration**

# %%
pip install kneed
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kneed in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.22.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from kneed) (1.10.1)

# %%
#menampilkan Grafik
import matplotlib.pyplot as plt
import seaborn as sns

#data Transformation
import pandas as pd
import numpy as np

#membanru dalam pembuatan model dan mempersiapkan data
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, make_scorer
from sklearn.preprocessing import MinMaxScaler
from kneed import KneeLocator

#model yang digunakan
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

#model Clustering
from sklearn.cluster import KMeans 

#magic line untuk matplotlib
# %matplotlib inline

# %%
#membaca data
url =  ('https://raw.githubusercontent.com/kilua762/malnutrition-classification/main/Data/Stunting.xlsx')
data_stunting = pd.read_excel(url)

# %%
#Didalam data terdapat beberapa char non-ascii jadi di hilangkan dahulu
data_stunting = data_stunting.applymap(lambda x : x.replace('\xa0', '') if type(x) == str else x)

data_stunting.sample(10)
# Out:
#                   NIK              Nama JK   Tgl Lahir BB Lahir TB Lahir  \
# 253  5305420101218702  JASON N. TNAAUNI  L  2021-01-25      2.4       47
# 174  5305422602190000    STEFANUS TAKUA  L  2019-02-26      2.3      NaN
# 285  5305422112209906        BY NAIHELI  L  2020-12-21      2.9       48
# 273  5305421202209929  ABRAHAM F. FALLO  L  2020-02-12        2       47
# 62   5305426712198397   KRISTINA MANUNI  P  2019-12-27      2.8        0
# 71   5303207005170001     SEFANIA OMENU  P  2017-05-30      2.7        0
# 93   5305426305199763     BELA SENGKOEN  P  2019-05-23      2.6      NaN
# 135        6707184980  HERLISTA NAITILI  P  2018-07-27      2.6       48
# 133  5305421911180000    YANGGA A. TAUS  L  2018-11-19      2.7      NaN
# 109  5305421405190000     REHAN PAINEON  L  2019-05-13        3       48
#
#                Nama Ortu                 Prov            Kab/Kota  \
# 253    AGUSTINUS TNAAUNI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 174     YEREMIAS USFINIT  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 285        YOSEP NAIHELI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 273           IRTO FALLO  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 62     DOMINIKUS NAITILI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 71            ANDE OMENU  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 93   VINSENSIUS SENGKOEN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 135   FREDERIKUS NAITILI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 133        YOSEP A. TAUS  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 109  FERDINANDUS PAINEON  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
#
#               Kec  ... ZS BB/U           TB/U ZS TB/U        BB/TB  ZS BB/TB  \
# 253  INSANA BARAT  ...   -3.25  Sangat Pendek   -3.01  Gizi Kurang     -2.38
# 174  INSANA BARAT  ...   -2.57         Pendek   -2.92    Gizi Baik     -1.35
# 285  INSANA BARAT  ...   -1.11         Pendek   -2.78    Gizi Baik      0.35
# 273  INSANA BARAT  ...   -2.17  Sangat Pendek   -3.49    Gizi Baik     -0.54
# 62   INSANA BARAT  ...   -1.85         Pendek   -2.45    Gizi Baik     -0.66
# 71   INSANA BARAT  ...   -2.19  Sangat Pendek   -3.09    Gizi Baik     -0.37
# 93   INSANA BARAT  ...   -2.22         Pendek   -2.93    Gizi Baik     -0.62
# 135  INSANA BARAT  ...   -2.26         Pendek   -2.05    Gizi Baik     -1.54
# 133  INSANA BARAT  ...   -2.77  Sangat Pendek   -3.11    Gizi Baik     -1.47
# 109  INSANA BARAT  ...   -2.42  Sangat Pendek   -3.21    Gizi Baik     -0.83
#
#     Naik Berat Badan PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 253                N                 0       1.0     -    -
# 174                N                 0       1.0     -    -
# 285                T                 0       1.0     -    -
# 273                N                 0       1.0     -    -
# 62                 N                 0       1.0     -    -
# 71                 N                 0       1.0     -    -
# 93                 N                 0       1.0     -    -
# 135                N                 0       1.0     -    -
# 133                T                 0       1.0     -    -
# 109                T                 0       1.0     -    -
#
# [10 rows x 32 columns]

# %%
#Melihat info data
data_stunting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NIK                 311 non-null    object
#  1   Nama                311 non-null    object
#  2   JK                  311 non-null    object
#  3   Tgl Lahir           311 non-null    object
#  4   BB Lahir            311 non-null    object
#  5   TB Lahir            217 non-null    object
#  6   Nama Ortu           311 non-null    object
#  7   Prov                311 non-null    object
#  8   Kab/Kota            311 non-null    object
#  9   Kec                 311 non-null    object
#  10  Pukesmas            311 non-null    object
#  11  Desa/Kel            311 non-null    object
#  12  Posyandu            311 non-null    object
#  13  RT                  193 non-null    float64
#  14  RW                  193 non-null    float64
#  15  Alamat              311 non-null    object
#  16  Usia Saat Ukur      311 non-null    object
#  17  Tanggal Pengukuran  311 non-null    object
#  18  Berat               311 non-null    float64
#  19  Tinggi              311 non-null    float64
#  20  LiLA                285 non-null    float64
#  21  BB/U                311 non-null    object
#  22  ZS BB/U             311 non-null    float64
#  23  TB/U                311 non-null    object
#  24  ZS TB/U             311 non-null    float64
#  25  BB/TB               311 non-null    object
#  26  ZS BB/TB            311 non-null    float64
#  27  Naik Berat Badan    311 non-null    object
#  28  PMT Diterima (kg)   311 non-null    object
#  29  Jml Vit A           286 non-null    float64
#  30  KPSP                310 non-null    object
#  31  KIA                 311 non-null    object
# dtypes: float64(9), object(23)
# memory usage: 77.9+ KB

# %%
#Melihat data yang tidak ada nilainya atau null
data_stunting.isna().sum()
# Out:
# NIK                     0
# Nama                    0
# JK                      0
# Tgl Lahir               0
# BB Lahir                0
# TB Lahir               94
# Nama Ortu               0
# Prov                    0
# Kab/Kota                0
# Kec                     0
# Pukesmas                0
# Desa/Kel                0
# Posyandu                0
# RT                    118
# RW                    118
# Alamat                  0
# Usia Saat Ukur          0
# Tanggal Pengukuran      0
# Berat                   0
# Tinggi                  0
# LiLA                   26
# BB/U                    0
# ZS BB/U                 0
# TB/U                    0
# ZS TB/U                 0
# BB/TB                   0
# ZS BB/TB                0
# Naik Berat Badan        0
# PMT Diterima (kg)       0
# Jml Vit A              25
# KPSP                    1
# KIA                     0
# dtype: int64

# %%
# Mengatasi data yang tidak ada nilainya
data_stunting.dropna()
# Out:
#                   NIK                       Nama JK   Tgl Lahir BB Lahir  \
# 5    5305424808170000              RIVALDO METAN  L  2017-08-08      2.9
# 24   5303201003170001              marten naiobe  L  2017-03-10      2.3
# 30   5305426812191816  BERNADINA NATALIA NAISALI  P  2019-12-28        3
# 34   5305420612170001              PAULO D. BALA  L  2017-12-06        3
# 35   5305424211170001           ADRIELA N. OMENU  P  2017-11-02      2.6
# ..                ...                        ... ..         ...      ...
# 305  5305422507204717          ALEXAN M. NAITILI  L  2020-07-25      2.9
# 306  5305424808201533       FELISIA AIRIN BIKOLO  P  2020-08-08      2.5
# 307  5305426608209012               ALISKA G. UN  P  2020-08-26      3.7
# 308  5305420902219648          FEBRIANUS T. SURI  L  2021-02-09      2.6
# 309  5305424602219849              FEBRIANA PULE  P  2021-02-06        3
#
#     TB Lahir          Nama Ortu                 Prov            Kab/Kota  \
# 5          0       DEDI Y. FOLE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 24         0       david naiobe  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 30        48         YOS BANASE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 34         0   KLAUDIUS METBOKI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 35         0      FIDELIS OMENU  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# ..       ...                ...                  ...                 ...
# 305       49      YOSEPH G. ABI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 306       46        YULIUS KOLO  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 307       50           FELIX UN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 308       48  FLAVIANUS O. SURI  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
# 309       49        PAULUS KONO  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA
#
#               Kec  ... ZS BB/U    TB/U ZS TB/U        BB/TB  ZS BB/TB  \
# 5    INSANA BARAT  ...   -1.55  Pendek   -2.09    Gizi Baik     -0.41
# 24   INSANA BARAT  ...   -2.37  Pendek   -2.59    Gizi Baik     -1.24
# 30   INSANA BARAT  ...   -1.01  Pendek   -2.10    Gizi Baik      0.18
# 34   INSANA BARAT  ...   -2.42  Pendek   -2.18    Gizi Baik     -1.74
# 35   INSANA BARAT  ...   -1.79  Pendek   -2.92    Gizi Baik      0.01
# ..            ...  ...     ...     ...     ...          ...       ...
# 305  INSANA BARAT  ...   -1.50  Pendek   -2.22    Gizi Baik     -0.62
# 306  INSANA BARAT  ...   -3.29  Pendek   -2.81  Gizi Kurang     -2.57
# 307  INSANA BARAT  ...   -1.82  Pendek   -2.18    Gizi Baik     -1.05
# 308  INSANA BARAT  ...   -2.23  Pendek   -2.69    Gizi Baik     -1.17
# 309  INSANA BARAT  ...   -2.03  Pendek   -2.08    Gizi Baik     -1.34
#
#     Naik Berat Badan PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 5                  N                 0       1.0     -    -
# 24                 N                 0       1.0     -    -
# 30                 N                 0       1.0     -    -
# 34                 T                 0       1.0     -    -
# 35                 T                 0       1.0     -    -
# ..               ...               ...       ...   ...  ...
# 305                T                 0       1.0     -    -
# 306                T                 0       1.0     -    -
# 307                T                 0       1.0     -    -
# 308                T                 -       1.0     -    -
# 309                N                 -       1.0     -    -
#
# [125 rows x 32 columns]

# %%
#Melihat data presentase BB/U 
data_stunting['BB/U'].value_counts()/data_stunting.shape[0]*100
# Out:
# Kurang                51.446945
# Berat Badan Normal    33.440514
# Sangat Kurang         15.112540
# Name: BB/U, dtype: float64

# %%
#melihat data presentase TB/U
data_stunting['TB/U'].value_counts()/data_stunting.shape[0]*100
# Out:
# Pendek           80.385852
# Sangat Pendek    19.614148
# Name: TB/U, dtype: float64

# %%
#Melihat data presentase BB/TB
data_stunting['BB/TB'].value_counts()/data_stunting.shape[0]*100
# Out:
# Gizi Baik            81.993569
# Gizi Kurang          15.434084
# Risiko Gizi Lebih     1.929260
# Gizi Lebih            0.643087
# Name: BB/TB, dtype: float64

# %%
#mengubah jenis data jenis kelamin yang ketegorikal menjadi angka 
data_stunting['JK'].replace({'L':1, 'P':0}, inplace=True)

# %%
#Untuk mengubah data kategorical menjadi angka
le = LabelEncoder()

data_stunting['BB/U'] = le.fit_transform(data_stunting['BB/U']) #Kurang , Berat Badan Normal
data_stunting['TB/U'] = le.fit_transform(data_stunting['TB/U']) #Sangat Pendek, Pendek
data_stunting['BB/TB'] = le.fit_transform(data_stunting['BB/TB']) #Gizi Baik, Risiko Gizi Lebih

data_stunting.head()
# Out:
#                 NIK                  Nama  JK   Tgl Lahir BB Lahir TB Lahir  \
# 0  5305424212170000        MARYELA TETHUN   0  2017-12-02      2.9       48
# 1  5305422807170000    KRISTIAN J. NAIAKI   1  2017-07-28        0        0
# 2  5305420203180000     MARVILIANO ANAPAH   1  2018-03-02        0        0
# 3  5303205004170001   VERA CLARISCA TAONE   0  2017-04-10        0        0
# 4  5305425205180000  VALENSIA K. OEBNAMAN   0  2018-05-12      2.8        0
#
#          Nama Ortu                 Prov            Kab/Kota           Kec  \
# 0   FIDELIS TETHUN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 1      EDUARDUS OE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 2    GASPAR ANTOIN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 3   DALMASIUS ELAN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 4  VIDELIS OEBNAMA  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
#
#    ... ZS BB/U TB/U ZS TB/U  BB/TB  ZS BB/TB Naik Berat Badan  \
# 0  ...   -2.93    1   -3.42      0     -1.16                N
# 1  ...   -1.57    1   -3.86      3      1.23                N
# 2  ...   -2.83    0   -2.95      0     -1.70                N
# 3  ...   -2.72    0   -2.25      0     -1.98                T
# 4  ...   -1.90    0   -2.41      0     -0.68                T
#
#   PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 0                 0       1.0     -    -
# 1                 0       1.0     -    -
# 2                 0       1.0     -    -
# 3                 0       1.0     -    -
# 4                 0       1.0     -    -
#
# [5 rows x 32 columns]

# %%
#Mengubah value 0 pada BB Lahir menjadi median
data_stunting['BB Lahir'] = pd.to_numeric(data_stunting['BB Lahir'])
data_stunting['BB Lahir'] = data_stunting['BB Lahir'].apply(lambda x : data_stunting['BB Lahir'].median() if x <= 0 else x)

data_stunting.head()
# Out:
#                 NIK                  Nama  JK   Tgl Lahir  BB Lahir TB Lahir  \
# 0  5305424212170000        MARYELA TETHUN   0  2017-12-02       2.9       48
# 1  5305422807170000    KRISTIAN J. NAIAKI   1  2017-07-28       2.8        0
# 2  5305420203180000     MARVILIANO ANAPAH   1  2018-03-02       2.8        0
# 3  5303205004170001   VERA CLARISCA TAONE   0  2017-04-10       2.8        0
# 4  5305425205180000  VALENSIA K. OEBNAMAN   0  2018-05-12       2.8        0
#
#          Nama Ortu                 Prov            Kab/Kota           Kec  \
# 0   FIDELIS TETHUN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 1      EDUARDUS OE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 2    GASPAR ANTOIN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 3   DALMASIUS ELAN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 4  VIDELIS OEBNAMA  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
#
#    ... ZS BB/U TB/U ZS TB/U  BB/TB  ZS BB/TB Naik Berat Badan  \
# 0  ...   -2.93    1   -3.42      0     -1.16                N
# 1  ...   -1.57    1   -3.86      3      1.23                N
# 2  ...   -2.83    0   -2.95      0     -1.70                N
# 3  ...   -2.72    0   -2.25      0     -1.98                T
# 4  ...   -1.90    0   -2.41      0     -0.68                T
#
#   PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 0                 0       1.0     -    -
# 1                 0       1.0     -    -
# 2                 0       1.0     -    -
# 3                 0       1.0     -    -
# 4                 0       1.0     -    -
#
# [5 rows x 32 columns]

# %%
#Mengubah value 0 pada TB Lahir menjadi median
data_stunting['TB Lahir'] = pd.to_numeric(data_stunting['TB Lahir'])
data_stunting['TB Lahir'] = data_stunting['TB Lahir'].apply(lambda x : data_stunting['TB Lahir'].median() if x <= 0 else x)
data_stunting['TB Lahir'].fillna(data_stunting['TB Lahir'].median(), inplace=True)

data_stunting.head()
# Out:
#                 NIK                  Nama  JK   Tgl Lahir  BB Lahir  TB Lahir  \
# 0  5305424212170000        MARYELA TETHUN   0  2017-12-02       2.9      48.0
# 1  5305422807170000    KRISTIAN J. NAIAKI   1  2017-07-28       2.8      47.0
# 2  5305420203180000     MARVILIANO ANAPAH   1  2018-03-02       2.8      47.0
# 3  5303205004170001   VERA CLARISCA TAONE   0  2017-04-10       2.8      47.0
# 4  5305425205180000  VALENSIA K. OEBNAMAN   0  2018-05-12       2.8      47.0
#
#          Nama Ortu                 Prov            Kab/Kota           Kec  \
# 0   FIDELIS TETHUN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 1      EDUARDUS OE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 2    GASPAR ANTOIN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 3   DALMASIUS ELAN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 4  VIDELIS OEBNAMA  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
#
#    ... ZS BB/U TB/U ZS TB/U  BB/TB  ZS BB/TB Naik Berat Badan  \
# 0  ...   -2.93    1   -3.42      0     -1.16                N
# 1  ...   -1.57    1   -3.86      3      1.23                N
# 2  ...   -2.83    0   -2.95      0     -1.70                N
# 3  ...   -2.72    0   -2.25      0     -1.98                T
# 4  ...   -1.90    0   -2.41      0     -0.68                T
#
#   PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 0                 0       1.0     -    -
# 1                 0       1.0     -    -
# 2                 0       1.0     -    -
# 3                 0       1.0     -    -
# 4                 0       1.0     -    -
#
# [5 rows x 32 columns]

# %%
#Mengubah value usia menjadi sebuah angka
data_stunting['Usia Saat Ukur'] = data_stunting['Usia Saat Ukur'].apply(lambda x : float(x[0]))

data_stunting.head()
# Out:
#                 NIK                  Nama  JK   Tgl Lahir  BB Lahir  TB Lahir  \
# 0  5305424212170000        MARYELA TETHUN   0  2017-12-02       2.9      48.0
# 1  5305422807170000    KRISTIAN J. NAIAKI   1  2017-07-28       2.8      47.0
# 2  5305420203180000     MARVILIANO ANAPAH   1  2018-03-02       2.8      47.0
# 3  5303205004170001   VERA CLARISCA TAONE   0  2017-04-10       2.8      47.0
# 4  5305425205180000  VALENSIA K. OEBNAMAN   0  2018-05-12       2.8      47.0
#
#          Nama Ortu                 Prov            Kab/Kota           Kec  \
# 0   FIDELIS TETHUN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 1      EDUARDUS OE  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 2    GASPAR ANTOIN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 3   DALMASIUS ELAN  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
# 4  VIDELIS OEBNAMA  NUSA TENGGARA TIMUR  TIMOR TENGAH UTARA  INSANA BARAT
#
#    ... ZS BB/U TB/U ZS TB/U  BB/TB  ZS BB/TB Naik Berat Badan  \
# 0  ...   -2.93    1   -3.42      0     -1.16                N
# 1  ...   -1.57    1   -3.86      3      1.23                N
# 2  ...   -2.83    0   -2.95      0     -1.70                N
# 3  ...   -2.72    0   -2.25      0     -1.98                T
# 4  ...   -1.90    0   -2.41      0     -0.68                T
#
#    PMT Diterima (kg) Jml Vit A  KPSP  KIA
# 0                  0       1.0     -    -
# 1                  0       1.0     -    -
# 2                  0       1.0     -    -
# 3                  0       1.0     -    -
# 4                  0       1.0     -    -
#
# [5 rows x 32 columns]

# %%
#memilih kolom yang mempengaruhi data
data_stunting = data_stunting[['JK','TB Lahir', 'Usia Saat Ukur','Berat','Tinggi']]

data_stunting.head()
# Out:
#    JK  TB Lahir  Usia Saat Ukur  Berat  Tinggi
# 0   0      48.0             4.0   11.2    89.0
# 1   1      47.0             4.0   14.2    89.8
# 2   1      47.0             3.0   11.4    90.6
# 3   0      47.0             4.0   12.3    97.8
# 4   0      47.0             3.0   12.1    90.8

# %% [markdown]
# # **Cluster Data dengan K-Means**

# %%
X_means = data_stunting.iloc[:, 3:5]
X_means.head()
# Out:
#    Berat  Tinggi
# 0   11.2    89.0
# 1   14.2    89.8
# 2   11.4    90.6
# 3   12.3    97.8
# 4   12.1    90.8

# %%
array_x = np.array(X_means)
array_x
# Out:
# array([[11.2, 89. ],
#        [14.2, 89.8],
#        [11.4, 90.6],
#        [12.3, 97.8],
#        [12.1, 90.8],
#        [14.2, 97.5],
#        [ 9.3, 85.3],
#        [10.3, 88.8],
#        [11. , 85.7],
#        [12. , 90.1],
#        [11.4, 90.7],
#        [14.3, 97.4],
#        [10.5, 84.6],
#        [ 9.4, 81. ],
#        [ 9.2, 82.2],
#        [10.4, 78.1],
#        [10.2, 82.7],
#        [ 9.6, 78.6],
#        [12.3, 91.1],
#        [ 8.2, 78.5],
#        [14. , 92.7],
#        [13.2, 92.5],
#        [ 9.9, 84.2],
#        [ 9.8, 84. ],
#        [13.3, 97.5],
#        [11.4, 92.4],
#        [12.7, 92.4],
#        [12. , 95.7],
#        [12.3, 90.2],
#        [ 9. , 81.9],
#        [10.4, 80. ],
#        [ 9. , 80.2],
#        [ 9. , 79.3],
#        [ 8.5, 77. ],
#        [12.3, 95.2],
#        [13.1, 91.8],
#        [12.3, 97.4],
#        [11.5, 93.8],
#        [13.9, 97.9],
#        [13. , 91.8],
#        [10.9, 90. ],
#        [13.3, 95. ],
#        [11.3, 93.1],
#        [11.1, 93.6],
#        [11.4, 94.2],
#        [12. , 91. ],
#        [11.1, 87.3],
#        [10.4, 83. ],
#        [11.4, 83.6],
#        [11.2, 89.9],
#        [10.6, 85.9],
#        [11.5, 98.8],
#        [13.6, 88.1],
#        [12.3, 86.8],
#        [10.9, 89. ],
#        [10.3, 81.7],
#        [ 9.1, 81.1],
#        [10.1, 82.8],
#        [ 9.1, 83. ],
#        [ 9.7, 82.2],
#        [10. , 81.9],
#        [12.2, 89.2],
#        [ 9.5, 79.2],
#        [10.4, 84.5],
#        [10.8, 86.2],
#        [10.4, 81.9],
#        [ 9.2, 82.3],
#        [ 7.5, 74.1],
#        [10. , 78.3],
#        [13.8, 93.8],
#        [14. , 96.2],
#        [13. , 93.2],
#        [13. , 89.3],
#        [13.2, 92.9],
#        [14.1, 95.3],
#        [12.3, 92.8],
#        [ 9.3, 79.3],
#        [ 9.5, 82.4],
#        [ 9.9, 83.9],
#        [10.5, 88.4],
#        [11. , 85.8],
#        [10.6, 86.1],
#        [10.1, 84.3],
#        [10.2, 81.5],
#        [ 9.6, 79.1],
#        [11. , 94.1],
#        [12.3, 92.8],
#        [11.7, 92. ],
#        [13.2, 93.5],
#        [10.7, 89.5],
#        [ 9.8, 84. ],
#        [ 9.7, 83.8],
#        [ 9.7, 84.1],
#        [10.1, 82. ],
#        [10.1, 84.5],
#        [11.9, 89.3],
#        [11.7, 88.6],
#        [15.9, 97.1],
#        [12.9, 94. ],
#        [10.2, 88.7],
#        [11.7, 90. ],
#        [10.3, 87.3],
#        [10.8, 86.1],
#        [14.1, 97.1],
#        [12.5, 93.5],
#        [11.9, 93.5],
#        [11.3, 90.9],
#        [10.1, 84. ],
#        [10.8, 85.2],
#        [10.4, 82.7],
#        [10.5, 83.6],
#        [11.5, 90.3],
#        [11.8, 90. ],
#        [11.3, 87.8],
#        [ 8.2, 79.1],
#        [11. , 85.4],
#        [10.5, 84. ],
#        [ 9. , 79.7],
#        [10.3, 81.1],
#        [12.8, 96.5],
#        [ 8.1, 81. ],
#        [10.4, 83.5],
#        [11.3, 92.5],
#        [10.1, 81.8],
#        [11. , 82.2],
#        [11.4, 88.5],
#        [12.5, 93.1],
#        [10.4, 81.9],
#        [12.8, 97. ],
#        [14. , 97.4],
#        [14.3, 97. ],
#        [10.7, 88.8],
#        [11.6, 92.3],
#        [10.6, 86. ],
#        [11.6, 86.4],
#        [11.3, 91.1],
#        [10.3, 87.2],
#        [11.4, 93. ],
#        [10. , 84.9],
#        [11.4, 83.5],
#        [10.4, 85.5],
#        [ 9.3, 77.6],
#        [ 8.6, 76.8],
#        [ 9. , 79.2],
#        [ 9.5, 80.3],
#        [12.3, 88. ],
#        [13.6, 96.3],
#        [12.9, 97.6],
#        [11.4, 90.5],
#        [13.7, 96.2],
#        [13.4, 94. ],
#        [14.3, 95.5],
#        [14.9, 99.4],
#        [ 9.6, 85.3],
#        [10.2, 86.5],
#        [11.7, 88.2],
#        [10.9, 89.1],
#        [12. , 87.4],
#        [11.8, 90.5],
#        [ 9.7, 79.8],
#        [13.4, 92. ],
#        [12. , 95.8],
#        [11.6, 89.3],
#        [ 9.9, 84.5],
#        [13.5, 97. ],
#        [12.1, 93.8],
#        [12.7, 91. ],
#        [12.9, 92.9],
#        [12. , 93.2],
#        [11.6, 93.6],
#        [13.9, 98.6],
#        [13.1, 98. ],
#        [13.2, 94. ],
#        [12.4, 92.1],
#        [10.5, 85.1],
#        [11.3, 86.6],
#        [10.9, 89. ],
#        [10.6, 89.7],
#        [ 9.8, 87. ],
#        [10.5, 85.2],
#        [10. , 84.9],
#        [11.4, 86.5],
#        [ 8.8, 81.3],
#        [ 9.4, 84. ],
#        [11.6, 91. ],
#        [13.7, 97.8],
#        [14. , 97.7],
#        [12.4, 96.5],
#        [13.2, 93.4],
#        [13.2, 95. ],
#        [12. , 90.5],
#        [12.5, 89.1],
#        [11.6, 90.2],
#        [12. , 90.7],
#        [11.5, 90.8],
#        [11.5, 90.2],
#        [11.6, 89.7],
#        [11.1, 87.5],
#        [11.5, 87.7],
#        [11.4, 83.5],
#        [ 9.8, 83. ],
#        [10.4, 83.4],
#        [ 9.4, 78.3],
#        [ 9.3, 79.9],
#        [11.2, 82.3],
#        [12.3, 89.5],
#        [13.8, 93. ],
#        [11.5, 90.9],
#        [13.4, 95. ],
#        [13.3, 93.6],
#        [11. , 90. ],
#        [10.4, 86.8],
#        [12. , 87.9],
#        [11.5, 91. ],
#        [11.7, 96.6],
#        [13.4, 91.4],
#        [11.6, 89.7],
#        [12.1, 92.5],
#        [11.1, 88.8],
#        [11.8, 87.7],
#        [ 9.3, 82.9],
#        [ 9.2, 81. ],
#        [10.9, 86.5],
#        [10.8, 80.7],
#        [ 9.9, 78.8],
#        [ 9.2, 86.6],
#        [13.7, 99.6],
#        [11.9, 94. ],
#        [13.2, 93. ],
#        [12.5, 92.5],
#        [10.6, 84.5],
#        [12.4, 94.1],
#        [ 9.9, 83.8],
#        [ 9.7, 81.2],
#        [11.8, 92. ],
#        [10.1, 82.2],
#        [11. , 85. ],
#        [ 9.4, 77.1],
#        [ 8.9, 78.9],
#        [ 9. , 81.2],
#        [ 5.9, 55.8],
#        [ 5.9, 62. ],
#        [ 9. , 76.5],
#        [ 9. , 73.5],
#        [ 7.4, 69.5],
#        [ 3.1, 52. ],
#        [ 8.7, 78.4],
#        [ 7.6, 72.5],
#        [ 9.5, 77.7],
#        [ 8.9, 77.6],
#        [ 7.9, 74.3],
#        [ 9. , 71.7],
#        [ 5.6, 64.3],
#        [ 6.8, 69.1],
#        [ 8. , 65.5],
#        [ 6.6, 68.4],
#        [ 4.3, 52.7],
#        [ 8. , 73.8],
#        [11.5, 76. ],
#        [ 8.4, 76. ],
#        [ 7.8, 70.4],
#        [ 6.8, 70.6],
#        [ 6.2, 65.3],
#        [ 4. , 56.7],
#        [ 8.4, 79.7],
#        [ 7.5, 76. ],
#        [ 7.5, 72.1],
#        [ 7.6, 71. ],
#        [ 8.6, 79.9],
#        [ 8.5, 79.2],
#        [ 8.8, 73.4],
#        [ 5.2, 57. ],
#        [ 8.8, 77.2],
#        [ 9.5, 77.2],
#        [ 8. , 74.2],
#        [ 8.9, 75.7],
#        [ 8.5, 74.8],
#        [ 7.1, 70.2],
#        [ 6.9, 65.8],
#        [ 7. , 72.3],
#        [ 9.1, 79.5],
#        [ 9.2, 80. ],
#        [ 8.3, 76.7],
#        [ 9.7, 75.6],
#        [ 7.9, 73.1],
#        [ 8.9, 71. ],
#        [ 7.6, 70. ],
#        [ 6.1, 66.8],
#        [ 5.9, 63.7],
#        [10.6, 77.6],
#        [ 9.2, 76. ],
#        [ 9.3, 76. ],
#        [ 3. , 49.7],
#        [10.2, 80. ],
#        [10.3, 80. ],
#        [ 8.6, 76.8],
#        [ 6.5, 71. ],
#        [ 8.9, 67.5],
#        [ 7.7, 77.5],
#        [ 8.8, 76.6],
#        [ 9.4, 73.8],
#        [ 9.2, 78.5],
#        [ 9.2, 76. ],
#        [ 8.9, 79.8],
#        [ 9.8, 77.2],
#        [ 9.4, 77. ],
#        [ 7. , 72.9],
#        [ 8.2, 74.2],
#        [ 7.6, 69.7],
#        [ 7.1, 69.2],
#        [ 5.9, 62.5]])

# %%
from pandas.core.arrays.sparse import array
scaler_fit = MinMaxScaler()
scaled_x = scaler_fit.fit_transform(array_x)
scaled_x
# Out:
# array([[0.63565891, 0.78757515],
#        [0.86821705, 0.80360721],
#        [0.65116279, 0.81963928],
#        [0.72093023, 0.96392786],
#        [0.70542636, 0.82364729],
#        [0.86821705, 0.95791583],
#        [0.48837209, 0.71342685],
#        [0.56589147, 0.78356713],
#        [0.62015504, 0.72144289],
#        [0.69767442, 0.80961924],
#        [0.65116279, 0.82164329],
#        [0.87596899, 0.95591182],
#        [0.58139535, 0.6993988 ],
#        [0.49612403, 0.62725451],
#        [0.48062016, 0.65130261],
#        [0.57364341, 0.56913828],
#        [0.55813953, 0.66132265],
#        [0.51162791, 0.57915832],
#        [0.72093023, 0.82965932],
#        [0.40310078, 0.57715431],
#        [0.85271318, 0.86172345],
#        [0.79069767, 0.85771543],
#        [0.53488372, 0.69138277],
#        [0.52713178, 0.68737475],
#        [0.79844961, 0.95791583],
#        [0.65116279, 0.85571142],
#        [0.75193798, 0.85571142],
#        [0.69767442, 0.92184369],
#        [0.72093023, 0.81162325],
#        [0.46511628, 0.64529058],
#        [0.57364341, 0.60721443],
#        [0.46511628, 0.61122244],
#        [0.46511628, 0.59318637],
#        [0.42635659, 0.54709419],
#        [0.72093023, 0.91182365],
#        [0.78294574, 0.84368737],
#        [0.72093023, 0.95591182],
#        [0.65891473, 0.88376754],
#        [0.84496124, 0.96593186],
#        [0.7751938 , 0.84368737],
#        [0.6124031 , 0.80761523],
#        [0.79844961, 0.90781563],
#        [0.64341085, 0.86973948],
#        [0.62790698, 0.87975952],
#        [0.65116279, 0.89178357],
#        [0.69767442, 0.82765531],
#        [0.62790698, 0.75350701],
#        [0.57364341, 0.66733467],
#        [0.65116279, 0.67935872],
#        [0.63565891, 0.80561122],
#        [0.58914729, 0.7254509 ],
#        [0.65891473, 0.98396794],
#        [0.82170543, 0.76953908],
#        [0.72093023, 0.74348697],
#        [0.6124031 , 0.78757515],
#        [0.56589147, 0.64128257],
#        [0.47286822, 0.62925852],
#        [0.5503876 , 0.66332665],
#        [0.47286822, 0.66733467],
#        [0.51937984, 0.65130261],
#        [0.54263566, 0.64529058],
#        [0.71317829, 0.79158317],
#        [0.50387597, 0.59118236],
#        [0.57364341, 0.69739479],
#        [0.60465116, 0.73146293],
#        [0.57364341, 0.64529058],
#        [0.48062016, 0.65330661],
#        [0.34883721, 0.48897796],
#        [0.54263566, 0.57314629],
#        [0.8372093 , 0.88376754],
#        [0.85271318, 0.93186373],
#        [0.7751938 , 0.87174349],
#        [0.7751938 , 0.79358717],
#        [0.79069767, 0.86573146],
#        [0.86046512, 0.91382766],
#        [0.72093023, 0.86372745],
#        [0.48837209, 0.59318637],
#        [0.50387597, 0.65531062],
#        [0.53488372, 0.68537074],
#        [0.58139535, 0.7755511 ],
#        [0.62015504, 0.72344689],
#        [0.58914729, 0.72945892],
#        [0.5503876 , 0.69338677],
#        [0.55813953, 0.63727455],
#        [0.51162791, 0.58917836],
#        [0.62015504, 0.88977956],
#        [0.72093023, 0.86372745],
#        [0.6744186 , 0.84769539],
#        [0.79069767, 0.87775551],
#        [0.59689922, 0.79759519],
#        [0.52713178, 0.68737475],
#        [0.51937984, 0.68336673],
#        [0.51937984, 0.68937876],
#        [0.5503876 , 0.64729459],
#        [0.5503876 , 0.69739479],
#        [0.68992248, 0.79358717],
#        [0.6744186 , 0.77955912],
#        [1.        , 0.9498998 ],
#        [0.76744186, 0.88777555],
#        [0.55813953, 0.78156313],
#        [0.6744186 , 0.80761523],
#        [0.56589147, 0.75350701],
#        [0.60465116, 0.72945892],
#        [0.86046512, 0.9498998 ],
#        [0.73643411, 0.87775551],
#        [0.68992248, 0.87775551],
#        [0.64341085, 0.8256513 ],
#        [0.5503876 , 0.68737475],
#        [0.60465116, 0.71142285],
#        [0.57364341, 0.66132265],
#        [0.58139535, 0.67935872],
#        [0.65891473, 0.81362725],
#        [0.68217054, 0.80761523],
#        [0.64341085, 0.76352705],
#        [0.40310078, 0.58917836],
#        [0.62015504, 0.71543086],
#        [0.58139535, 0.68737475],
#        [0.46511628, 0.6012024 ],
#        [0.56589147, 0.62925852],
#        [0.75968992, 0.93787575],
#        [0.39534884, 0.62725451],
#        [0.57364341, 0.67735471],
#        [0.64341085, 0.85771543],
#        [0.5503876 , 0.64328657],
#        [0.62015504, 0.65130261],
#        [0.65116279, 0.77755511],
#        [0.73643411, 0.86973948],
#        [0.57364341, 0.64529058],
#        [0.75968992, 0.94789579],
#        [0.85271318, 0.95591182],
#        [0.87596899, 0.94789579],
#        [0.59689922, 0.78356713],
#        [0.66666667, 0.85370741],
#        [0.58914729, 0.72745491],
#        [0.66666667, 0.73547094],
#        [0.64341085, 0.82965932],
#        [0.56589147, 0.75150301],
#        [0.65116279, 0.86773547],
#        [0.54263566, 0.70541082],
#        [0.65116279, 0.67735471],
#        [0.57364341, 0.71743487],
#        [0.48837209, 0.55911824],
#        [0.43410853, 0.54308617],
#        [0.46511628, 0.59118236],
#        [0.50387597, 0.61322645],
#        [0.72093023, 0.76753507],
#        [0.82170543, 0.93386774],
#        [0.76744186, 0.95991984],
#        [0.65116279, 0.81763527],
#        [0.82945736, 0.93186373],
#        [0.80620155, 0.88777555],
#        [0.87596899, 0.91783567],
#        [0.92248062, 0.99599198],
#        [0.51162791, 0.71342685],
#        [0.55813953, 0.73747495],
#        [0.6744186 , 0.77154309],
#        [0.6124031 , 0.78957916],
#        [0.69767442, 0.75551102],
#        [0.68217054, 0.81763527],
#        [0.51937984, 0.60320641],
#        [0.80620155, 0.84769539],
#        [0.69767442, 0.9238477 ],
#        [0.66666667, 0.79358717],
#        [0.53488372, 0.69739479],
#        [0.81395349, 0.94789579],
#        [0.70542636, 0.88376754],
#        [0.75193798, 0.82765531],
#        [0.76744186, 0.86573146],
#        [0.69767442, 0.87174349],
#        [0.66666667, 0.87975952],
#        [0.84496124, 0.97995992],
#        [0.78294574, 0.96793587],
#        [0.79069767, 0.88777555],
#        [0.72868217, 0.8496994 ],
#        [0.58139535, 0.70941884],
#        [0.64341085, 0.73947896],
#        [0.6124031 , 0.78757515],
#        [0.58914729, 0.80160321],
#        [0.52713178, 0.74749499],
#        [0.58139535, 0.71142285],
#        [0.54263566, 0.70541082],
#        [0.65116279, 0.73747495],
#        [0.4496124 , 0.63326653],
#        [0.49612403, 0.68737475],
#        [0.66666667, 0.82765531],
#        [0.82945736, 0.96392786],
#        [0.85271318, 0.96192385],
#        [0.72868217, 0.93787575],
#        [0.79069767, 0.8757515 ],
#        [0.79069767, 0.90781563],
#        [0.69767442, 0.81763527],
#        [0.73643411, 0.78957916],
#        [0.66666667, 0.81162325],
#        [0.69767442, 0.82164329],
#        [0.65891473, 0.82364729],
#        [0.65891473, 0.81162325],
#        [0.66666667, 0.80160321],
#        [0.62790698, 0.75751503],
#        [0.65891473, 0.76152305],
#        [0.65116279, 0.67735471],
#        [0.52713178, 0.66733467],
#        [0.57364341, 0.6753507 ],
#        [0.49612403, 0.57314629],
#        [0.48837209, 0.60521042],
#        [0.63565891, 0.65330661],
#        [0.72093023, 0.79759519],
#        [0.8372093 , 0.86773547],
#        [0.65891473, 0.8256513 ],
#        [0.80620155, 0.90781563],
#        [0.79844961, 0.87975952],
#        [0.62015504, 0.80761523],
#        [0.57364341, 0.74348697],
#        [0.69767442, 0.76553106],
#        [0.65891473, 0.82765531],
#        [0.6744186 , 0.93987976],
#        [0.80620155, 0.83567134],
#        [0.66666667, 0.80160321],
#        [0.70542636, 0.85771543],
#        [0.62790698, 0.78356713],
#        [0.68217054, 0.76152305],
#        [0.48837209, 0.66533066],
#        [0.48062016, 0.62725451],
#        [0.6124031 , 0.73747495],
#        [0.60465116, 0.62124248],
#        [0.53488372, 0.58316633],
#        [0.48062016, 0.73947896],
#        [0.82945736, 1.        ],
#        [0.68992248, 0.88777555],
#        [0.79069767, 0.86773547],
#        [0.73643411, 0.85771543],
#        [0.58914729, 0.69739479],
#        [0.72868217, 0.88977956],
#        [0.53488372, 0.68336673],
#        [0.51937984, 0.63126253],
#        [0.68217054, 0.84769539],
#        [0.5503876 , 0.65130261],
#        [0.62015504, 0.70741483],
#        [0.49612403, 0.5490982 ],
#        [0.45736434, 0.58517034],
#        [0.46511628, 0.63126253],
#        [0.2248062 , 0.12224449],
#        [0.2248062 , 0.24649299],
#        [0.46511628, 0.53707415],
#        [0.46511628, 0.47695391],
#        [0.34108527, 0.39679359],
#        [0.00775194, 0.04609218],
#        [0.44186047, 0.5751503 ],
#        [0.35658915, 0.45691383],
#        [0.50387597, 0.56112224],
#        [0.45736434, 0.55911824],
#        [0.37984496, 0.49298597],
#        [0.46511628, 0.44088176],
#        [0.20155039, 0.29258517],
#        [0.29457364, 0.38877756],
#        [0.3875969 , 0.31663327],
#        [0.27906977, 0.3747495 ],
#        [0.10077519, 0.06012024],
#        [0.3875969 , 0.48296593],
#        [0.65891473, 0.52705411],
#        [0.41860465, 0.52705411],
#        [0.37209302, 0.41482966],
#        [0.29457364, 0.41883768],
#        [0.24806202, 0.31262525],
#        [0.07751938, 0.14028056],
#        [0.41860465, 0.6012024 ],
#        [0.34883721, 0.52705411],
#        [0.34883721, 0.4488978 ],
#        [0.35658915, 0.42685371],
#        [0.43410853, 0.60521042],
#        [0.42635659, 0.59118236],
#        [0.4496124 , 0.4749499 ],
#        [0.17054264, 0.14629259],
#        [0.4496124 , 0.5511022 ],
#        [0.50387597, 0.5511022 ],
#        [0.3875969 , 0.49098196],
#        [0.45736434, 0.52104208],
#        [0.42635659, 0.50300601],
#        [0.31782946, 0.41082164],
#        [0.30232558, 0.32264529],
#        [0.31007752, 0.45290581],
#        [0.47286822, 0.59719439],
#        [0.48062016, 0.60721443],
#        [0.41085271, 0.54108216],
#        [0.51937984, 0.51903808],
#        [0.37984496, 0.46893788],
#        [0.45736434, 0.42685371],
#        [0.35658915, 0.40681363],
#        [0.24031008, 0.34268537],
#        [0.2248062 , 0.28056112],
#        [0.58914729, 0.55911824],
#        [0.48062016, 0.52705411],
#        [0.48837209, 0.52705411],
#        [0.        , 0.        ],
#        [0.55813953, 0.60721443],
#        [0.56589147, 0.60721443],
#        [0.43410853, 0.54308617],
#        [0.27131783, 0.42685371],
#        [0.45736434, 0.35671343],
#        [0.36434109, 0.55711423],
#        [0.4496124 , 0.53907816],
#        [0.49612403, 0.48296593],
#        [0.48062016, 0.57715431],
#        [0.48062016, 0.52705411],
#        [0.45736434, 0.60320641],
#        [0.52713178, 0.5511022 ],
#        [0.49612403, 0.54709419],
#        [0.31007752, 0.46492986],
#        [0.40310078, 0.49098196],
#        [0.35658915, 0.4008016 ],
#        [0.31782946, 0.39078156],
#        [0.2248062 , 0.25651303]])

# %%
#perhitungan cluster dengan k-means dan visualisasi dengan metode ELBOW
wcss = []
for i in range (1,11) :
  kmeans = KMeans(n_clusters= i, init = 'k-means++', random_state = 42)
  kmeans.fit(X_means)
  wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('wcss')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
sse = []
for k in range(1, 11):
  kmeans = KMeans(n_clusters= k, init = 'k-means++', random_state = 42)
  kmeans.fit(scaled_x)
  sse.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator( range(1, 11), sse, curve="convex", direction="decreasing" )
kl.elbow
# Out:
# 3

# %%
kmeans = KMeans(n_clusters = 3, random_state=42)

# %%
kmeans.fit(scaled_x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
data_stunting["cluster"] = kmeans.labels_

# %%
output = plt.scatter(scaled_x[: ,0], scaled_x[: ,1], s = 10, c = data_stunting.cluster)
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=100, alpha=1, marker="o");
plt.title("Hasil clustering K-Means")
plt.colorbar (output)
plt.show()

# %% [markdown]
# keterangan tabel:
#
#
# 1.   titik merah merupakan penanda titik lokasi
#   cluster
# 2.   warna hitam merupakan cluster 0
# 3.  warna hijau merupakan cluster 1
# 4. warna kuning merupakan cluster 2
#
# Kesimpulan warna hitam/cluster 0 nilai yang relatif sedang, warna hijau/cluster 1 nilai yang relatif rendah, warna kuning/cluster 2 merupakan kelompok yang relatif tinggi

# %%
data_stunting.sample(10)
# Out:
#      JK  TB Lahir  Usia Saat Ukur  Berat  Tinggi  cluster
# 54    1      47.0             3.0   10.9    89.0        2
# 236   1      49.0             2.0   11.0    85.0        0
# 251   1      48.0             1.0    9.0    71.7        1
# 145   0      47.0             3.0   12.3    88.0        2
# 56    1      47.0             2.0    9.1    81.1        0
# 216   1      47.0             3.0   11.6    89.7        2
# 246   1      49.0             1.0    8.7    78.4        0
# 222   1      47.0             2.0   10.9    86.5        0
# 248   1      49.0             1.0    9.5    77.7        0
# 134   1      47.0             2.0   11.6    86.4        2

# %%
#Export File to .csv
data_stunting.to_csv("StuntingCluster.csv",index = False)

# %% [markdown]
# # **Modelling**

# %%
# inisialisasi data dan target
target = data_stunting['cluster']
features = data_stunting.drop(['cluster'], axis = 1)

# %%
# Membagi data menjadi menjadi training set dan testing set
X_train, X_test, y_train, y_test = train_test_split(features.to_numpy(), target, test_size = 0.2, random_state = 0)

# %%
# Train dan evaluasi model
def fit_eval_model(model, train_features, y_train, test_features, y_test):
  results = {}
  # train model
  model.fit(train_features, y_train)
  #test model 
  train_predicted = model.predict(train_features)
  test_predicted = model.predict(test_features)
  #classification report and confusion matrix
  results['classification_report'] = classification_report(y_test, test_predicted)
  results['confusion_matrix'] = confusion_matrix(y_test, test_predicted)
  results['accuracy'] = format(accuracy_score(y_test, test_predicted)*100)

  return results

# %% [markdown]
# fungsi : mencoba dan mengevaluasi klasifikasi pada machine learning
#
# model: klasifikasi machine learning
# train features: fitur pada train data
# y_train = pengecekan cluster sebanyak 80%
# test_features = fitur selain cluster
# y_test = testing cluster sebanyak 20%
#
# hasil berupa klasifikation report, confusion matrix, dan akurasi

# %%
#inisialisasi model
sv = SVC(random_state = 1, probability=True)
rf = RandomForestClassifier(random_state =1)
mnb = MultinomialNB()
lr = LogisticRegression(random_state=0)

# evaluasi model
results = {}
for cls in [sv, rf, mnb, lr]:
  cls_name = cls.__class__.__name__
  results[cls_name] = {}
  results[cls_name] = fit_eval_model(cls, X_train, y_train, X_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#melihat hasil classifier
for result in results:
  print (result)
  print()
  for i in results[result]:
    print (i, ':')
    print(results[result][i])
    print()
  print('______')
  print()
# Out:
# SVC
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89        31
#            1       1.00      0.62      0.77         8
#            2       0.88      0.96      0.92        24
#
#     accuracy                           0.89        63
#    macro avg       0.92      0.83      0.86        63
# weighted avg       0.89      0.89      0.89        63
#
#
# confusion_matrix :
# [[28  0  3]
#  [ 3  5  0]
#  [ 1  0 23]]
#
# accuracy :
# 88.88888888888889
#
# ______
#
# RandomForestClassifier
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        31
#            1       1.00      1.00      1.00         8
#            2       1.00      0.96      0.98        24
#
#     accuracy                           0.98        63
#    macro avg       0.99      0.99      0.99        63
# weighted avg       0.98      0.98      0.98        63
#
#
# confusion_matrix :
# [[31  0  0]
#  [ 0  8  0]
#  [ 1  0 23]]
#
# accuracy :
# 98.4126984126984
#
# ______
#
# MultinomialNB
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83        31
#            1       1.00      0.62      0.77         8
#            2       0.79      0.96      0.87        24
#
#     accuracy                           0.84        63
#    macro avg       0.89      0.80      0.82        63
# weighted avg       0.85      0.84      0.84        63
#
#
# confusion_matrix :
# [[25  0  6]
#  [ 3  5  0]
#  [ 1  0 23]]
#
# accuracy :
# 84.12698412698413
#
# ______
#
# LogisticRegression
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94        31
#            1       1.00      0.88      0.93         8
#            2       0.92      0.96      0.94        24
#
#     accuracy                           0.94        63
#    macro avg       0.95      0.92      0.94        63
# weighted avg       0.94      0.94      0.94        63
#
#
# confusion_matrix :
# [[29  0  2]
#  [ 1  7  0]
#  [ 1  0 23]]
#
# accuracy :
# 93.65079365079364
#
# ______
